# %% [markdown]
# <a href="https://colab.research.google.com/github/SageCas/Money-Expense-Report/blob/main/Pollution_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = 'https://raw.githubusercontent.com/kmath22/Math-200/refs/heads/main/Pollution%20Case%20Study%201.o%20-%20Sheet1.csv'
case_df = pd.read_csv(data)

case_df
