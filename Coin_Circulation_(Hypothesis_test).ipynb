# %% [markdown]
# <a href="https://colab.research.google.com/github/SageCas/Money-Expense-Report/blob/main/Coin_Circulation_(Hypothesis_test).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
link = 'https://raw.githubusercontent.com/kmath22/Math-200/refs/heads/main/Coin%20Circulation%20%20Research%201.0%20-%20Form%20Responses%201.csv'

df = pd.read_csv(link)

df
# Out:
#              Timestamp         Coin_type Mint  Year  Age
# 0    3/4/2021 12:08:33           quarter    S  2015    9
# 1    3/4/2021 12:09:05             penny    D  2012   12
# 2    3/4/2021 12:09:36             penny    D  1975   49
# 3    3/4/2021 16:40:48  half dollar coin    D  2000   24
# 4    3/4/2021 18:16:18           quarter    D  2001   23
# ..                 ...               ...  ...   ...  ...
# 253                NaN              dime    P  2024    0
# 254                NaN              dime    P  2022    2
# 255                NaN            nickel    P  2014   10
# 256                NaN              dime    P  2022    2
# 257                NaN  half dollar coin    P  1983   41
#
# [258 rows x 5 columns]

# %%
# prompt: remove Age values greater than 200

# Assuming 'Age' is the column name containing the age values
df = df[df['Age'] <= 200]

# %%
df.describe().round(2)

# %%
fig,axes = plt.subplots(3,1, figsize =(8,7))
ax1 = sns.histplot( ax = axes[0], x ='Age', data =df,)
ax2 = sns.boxplot( ax = axes[1], x = 'Age' , data =df)
ax3 = sns.stripplot(ax = axes[2], x ='Age', data =df, size=5)
ax4 = sns.pointplot( ax = axes[2], x='Age', data = df, capsize=.5, errorbar=('ci' , 95), color ='r',)
ax1.axvline(x = 30, color = 'r', label = 'axvline - full height', linestyle = '--')
ax2.axvline(x = 30, color = 'r', label = 'axvline - full height', linestyle = '--')
ax3.axvline(x = 30, color = 'g', label = 'axvline - full height', linestyle = '--')
plt.show()

# %%
pip install bioinfokit

# %%
#Method 1 (Use the bioinfokit Library)
from bioinfokit.analys import stat

# %%
res = stat()
res.ttest(df=df, test_type=1, res='Age', mu=30 )
print(res.summary)

# %% [markdown]
# # 1 Proportion Z Test
#
# ![image.png](data:image/png;base64,...)

# %%
pip install researchpy

# %%
import researchpy as rp

# %%
rp.summary_cat(df['Coin_type'])

# %%
df['Coin_type'].value_counts(normalize = True).plot(kind ='pie')

# %%
#1 Sample Proportion Z test (Read statsmodels library)
from statsmodels.stats.proportion import proportions_ztest

# %%
#For alternative us [‘two-sided’, ‘smaller’, ‘larger’]
z, pval = proportions_ztest(count= , nobs= , value= , alternative='')
print('z value :' , z.round(3))
print('P value :' , pval.round(3))

# %% [markdown]
# # Part # 2  Use the diamond dataset

# %%
#Upload the diamond dataset
import pandas as pd
data =''

diamond_df = pd.read_csv(data)
diamond_df.head()
